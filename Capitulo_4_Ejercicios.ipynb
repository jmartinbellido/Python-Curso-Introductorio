# %% [markdown]
# # **Introducción a Python para Análisis de Datos**
# ## Capítulo 4: Limpieza de Datos - Soluciones a Ejercicios
# ---
# Acerca de este notebook
# * **Autor:** Juan Martin Bellido
# * **Descripción:** *este notebook incluye las soluciones a los ejercicios del capítulo 4*
# * **¿Feedback? ¿comentarios?** Por favor compártelo conmigo escribiéndome por [LinkedIn](https://www.linkedin.com/in/jmartinbellido/)

# %% [markdown]
# # Capítulo 4: Ejercicios
# ---

# %% [markdown]
# ### Ejercicio #1
#
# ##### EX 1.A Identificar columnas con valores nulos en el dataframe.
# ##### EX 1.B ¿Cuántas películas hay con valores nulos para el campo *director_name*?
# ##### EX 1.C Reemplazar valores nulos en *director_name* por "unknown".
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/movies.csv

# %%
import pandas as pd
df_movies = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/movies.csv")
df_movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# EX 1.A
df_movies.isna().any()
# Out:
# color                         True
# director_name                 True
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                  True
# actor_1_facebook_likes        True
# gross                         True
# genres                       False
# actor_1_name                  True
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                  True
# facenumber_in_poster          True
# plot_keywords                 True
# movie_imdb_link              False
# num_user_for_reviews          True
# language                      True
# country                       True
# content_rating                True
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                   False
# aspect_ratio                  True
# movie_facebook_likes         False
# dtype: bool

# %%
# EX 1.B
cond = df_movies['director_name'].isna()
len(df_movies[cond])
# Out:
# 102

# %%
# EX 1.C
df_movies['director_name'] = df_movies['director_name'].fillna('unknown')

# %% [markdown]
# ### Ejercicio #2
#
# Detectar empresas que sean outliers en cantidad de empleados.
#
# ##### EX 2.A Utilizando distribución normal
# ##### EX 2.B Utilizando el método del rango intercuartílico
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv

# %%
import pandas as pd
from scipy import stats
df_fortune = pd.read_csv('https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv')
df_fortune.dtypes
# Out:
# Rank          int64
# Company      object
# Sector       object
# Industry     object
# Location     object
# Revenue       int64
# Profits       int64
# Employees     int64
# dtype: object

# %%
# 2.A
# normalizamos variable
df_fortune["z_Employees"] = stats.zscore(df_fortune["Employees"],nan_policy='omit').round(2)

# %%
# filtramos filas, seleccionamos columnas, ordenamos filas
cond = abs(df_fortune['z_Employees'])>3
df_fortune[cond][['Company','Employees','z_Employees']].sort_values("z_Employees",ascending=False)
# Out:
#                 Company  Employees  z_Employees
# 0               Walmart    2300000        25.08
# 217          Yum Brands     505000         5.22
# 16               Kroger     431000         4.40
# 108          McDonald’s     420000         4.28
# 30                  IBM     411798         4.19
# 27           Home Depot     385000         3.89
# 37               Target     341000         3.41
# 47                  UPS     341240         3.41
# 10     General Electric     333000         3.32
# 3    Berkshire Hathaway     331000         3.30
# 57                FedEx     323035         3.21

# %%
# 2.B
# calculamos el IQR
IQR = df_fortune["Employees"].quantile(0.75) - df_fortune["Employees"].quantile(0.25)

# %%
# calculamos los límites superiores e inferiores, según el método IQR
sup_lim = IQR * 1.5 + df_fortune["Employees"].quantile(0.75)
inf_lim = df_fortune["Employees"].quantile(0.25) - IQR * 1.5

# %%
# creamos condiciones para capturar las filas donde el campo empleados quede por fuera de los límites
cond = df_fortune["Employees"] > sup_lim
cond_2 = df_fortune["Employees"] < inf_lim

# filtramos, seleccionamos columnas, ordenamos filas
df_fortune[cond | cond_2][['Company','Employees']].sort_values("Employees",ascending=False)
# Out:
#                 Company  Employees
# 0               Walmart    2300000
# 217          Yum Brands     505000
# 16               Kroger     431000
# 108          McDonald’s     420000
# 30                  IBM     411798
# ..                  ...        ...
# 239         Toys “R” Us      62000
# 35             Alphabet      61814
# 435  Jones Lang LaSalle      61500
# 13              Chevron      61500
# 119            Raytheon      61000
#
# [120 rows x 2 columns]

# %% [markdown]
# ### Ejercicio #3
#
# El dataset contiene productos de Amazon. Limpiar las categorías de productos hasta obtener las 3 primeras para cada producto.
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/amzn_products.txt

# %%
import pandas as pd
df_amzn_products = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/amzn_products.txt",sep="\t")
df_amzn_products.dtypes
# Out:
# asin          object
# brand         object
# categories    object
# dtype: object

# %%
# utilizamos método .str.split() para separar valores de un campo de texto según delimitador
df_amzn_products['categories'].str.split(pat=',',expand=True,n=3)\
    .rename(columns={0:'cat_1',1:'cat_2',2:'cat_3'})\
    .join(df_amzn_products)\
    .loc[:,['asin','brand','cat_1','cat_2','cat_3']]
# Out:
#                                 asin                   brand  \
# 0                         B0168YIWSI               Microsoft
# 1              B018K251JE,B00VILQKQ8                 Boytone
# 2                         B00C78VIUE                   Sanus
# 3                         B075WKS4D8           Ultimate Ears
# 4                         B000YA33DC                 Lowepro
# 5                         B00505EZYW                 Corsair
# 6                         B00WBS31OQ  Sdi Technologies, Inc.
# 7              B0172DS3ME,B00NTJKAXG        Verizon Wireless
# 8                         B00R5WGT2E                     JVC
# 9                         B00V631478                     JBL
# 10                        B009AEMB6I                  Lenovo
# 11                        B06XSGYCHC                Siriusxm
# 12                        B012ASF1WQ                     Pny
# 13             B01LYGPB3J,B011QHAOWO             Sling Media
# 14             B01J0BFAAO,B019Q88VAM                    Sony
# 15                        B004OVE61U                 Midland
# 16                        B007QOIP3M                    Sony
# 17                        B01ETTL6LE                    Sony
# 18                        B009E6J1BU                 Toshiba
# 19                        B00B7C07LC          Power Acoustik
# 20                        B01700RNIO         House of Marley
# 21                        B005YXXS4I                  Yamaha
# 22                        B00U0VEGRM               DreamWave
# 23  B00Q397RJY,B005LKCDR2,B001447Z8Q                Glengery
# 24                        B06XVDYHQX                    Dell
# 25                        B008FH1PJA               MEE audio
# 26                        B071ZVQVFQ                 Samsung
# 27                        B001AVRD62                  Yamaha
# 28                        B00TVFO08S                    Bose
# 29                        B01KUAMCWI                Logitech
# 30                        B01CEAT9ZU                    Sony
# 31             B01MUG578I,B072MP2CFG                    Sony
# 32                        B00IWQ3YPC                    Sony
# 33                        B000O3TFWW                  Yamaha
# 34                        B00LIL7YVI                Motorola
# 35  B00170HCOO,B001BBT7RY,B00170O1HK   Definitive Technology
# 36                        B0038NMC8O                  Alpine
# 37                        B01364B00K                  Belkin
# 38                        B00F6PRSMW        Bowers & Wilkins
# 39                        B01AEW9E46                     JBL
# 40                        B00009WCBT         CLARITY-TELECOM
# 41                        B00RZYD51A         House of Marley
# 42                        B0742RMVQ8                 Toshiba
# 43                        B00L2EWRW2                  Kicker
# 44                        B00PASUGTC                     SVS
# 45                        B008JJLZ7G                      WD
# 46                        B073JHHNJ9                 Netgear
# 47                        B00KGGK1J8                 Samsung
# 48                        B00IAKLM54                Logitech
# 49  B005MJHFHK,B00VXW0J5A,B00OY50CZU             Peerless-AV
#
#                             cat_1                                      cat_2  \
# 0                     Electronics                                  Computers
# 1                     Electronics                     Portable Audio & Video
# 2       Audio & Video Accessories                                  TV Mounts
# 3     Portable Bluetooth Speakers              Bluetooth & Wireless Speakers
# 4                     Photography                     Photography Bags Cases
# 5                       Computers                               Memory (RAM)
# 6     Portable Bluetooth Speakers                                    Stereos
# 7                       Computers                                 Networking
# 8                     Electronics                             Portable Audio
# 9                     Electronics                  Car & Vehicle Electronics
# 10            Computers & Tablets         Computer Accessories & Peripherals
# 11                Satellite Radio                           Satellite Radios
# 12                 Desktop Memory             Computers/Tablets & Networking
# 13                     TV & Video                    Media Streaming Players
# 14    Portable Bluetooth Speakers                Audio Docks & Mini Speakers
# 15                    Electronics                             Portable Audio
# 16                    Electronics                                  Computers
# 17    Portable Bluetooth Speakers                Audio Docks & Mini Speakers
# 18    Internal Solid State Drives                    Computers & Accessories
# 19                   Auto & Tires                           Auto Electronics
# 20                     Headphones                       Bluetooth Headphones
# 21                             TV                         Video & Home Audio
# 22    Portable Bluetooth Speakers              Bluetooth & Wireless Speakers
# 23                 stone products                                electronics
# 24                      Computers                      Desktops Workstations
# 25                     Headphones                       Bluetooth Headphones
# 26                  LED & LCD TVs                                    All TVs
# 27              Surround Speakers                       Electronics Features
# 28              Surround Speakers                                         TV
# 29                      Computers                           Mice & Mice Pads
# 30                    Electronics       CD Players & Digital Media Receivers
# 31    Portable Bluetooth Speakers                Audio Docks & Mini Speakers
# 32                    Electronics                       Home Audio & Theater
# 33  In-Wall & In-Ceiling Speakers                                Electronics
# 34                    Electronics                       Cameras & Camcorders
# 35               Outdoor Speakers                       Electronics Features
# 36                   Auto & Tires                           Auto Electronics
# 37                      Computers  Portable Battery Packs yxdasxffaabvrfusya
# 38                     Headphones                                Electronics
# 39                         Mobile                                 Headphones
# 40                         Office                          Office Technology
# 41                     Headphones                                Electronics
# 42           Home Theater Systems                     Portable Audio & Video
# 43                    Electronics                       Home Audio & Theater
# 44              Speaker Separates                    Center Channel Speakers
# 45                      Computers                       Internal Hard Drives
# 46                      Computers        Wireless Networking rwtaqbstbwzzteq
# 47                    Accessories                       Portable Power Banks
# 48                    Electronics                     Accessories & Supplies
# 49                         Office        Projectors & Presentation Equipment
#
#                                  cat_3
# 0                 Computer Accessories
# 1                 Home Audio & Theater
# 2               TV Accessories & Parts
# 3               Portable Audio & Video
# 4                          Camera Bags
# 5              Computers & Accessories
# 6                            Computers
# 7       Home Networking & Connectivity
# 8                         Auto & Tires
# 9                      Car Electronics
# 10                  Laptop Accessories
# 11           Car & Vehicle Electronics
# 12                        Memory (RAM)
# 13                      New Technology
# 14               Used:TV Entertainment
# 15                     MP3 Accessories
# 16                Computer Accessories
# 17       Bluetooth & Wireless Speakers
# 18  Computer Accessories & Peripherals
# 19         Car Speakers and Subwoofers
# 20                   On-Ear Headphones
# 21                           Receivers
# 22              Portable Audio & Video
# 23                 Parts & Accessories
# 24                   Desktop Computers
# 25                      All Headphones
# 26                     Refurbished TVs
# 27              Surround Sound Systems
# 28                  Video & Home Audio
# 29                Computer Accessories
# 30                     Car Electronics
# 31       Bluetooth & Wireless Speakers
# 32                        Home Theater
# 33                 In-Ceiling Speakers
# 34                      All Camcorders
# 35                         Electronics
# 36         Car Speakers and Subwoofers
# 37       Portable Chargers/Power Packs
# 38                 Over-Ear Headphones
# 39                Bluetooth Headphones
# 40                Phones & Accessories
# 41                 Over-Ear Headphones
# 42                         Electronics
# 43                          Home Audio
# 44                         Electronics
# 45                     Internal Drives
# 46                          Networking
# 47       Portable Chargers/Power Packs
# 48           Audio & Video Accessories
# 49           Audio Visual Presentation
